# %%
from pymongo import MongoClient

connection_string = 'mongodb://localhost:27017/'
client = MongoClient(connection_string, username='root', password='root')
db = client["PRY01"]
posts_collection = db['posts']
comentarios_collection = db['comentarios']
reacciones_collection = db['reacciones']

# %%
def insertar_post(user_id: int, text: str, images: list, reacciones: list, comentarios: list):
        post = {
            'usuario_id' : user_id,
            'text' : text,
            'images' : images,
            'reacciones' : reacciones,
            'comentarios' : comentarios
        }

        resultado = posts_collection.insert_one(post)
        print(resultado.inserted_id)

def obtener_posts(user_id):
    res = posts_collection.find({"usuario_id": user_id})
    return list(res)

def post_id(id):
     return id

def insertar_comentario(user_id: int, post_id: str, coment_text: str):
# coment_id: int
# user_id: int
# coment_text: str
# reacciones: list
    comentario = {
        'coment_id': 0,
        'post_id' : post_id,
        'user_id' : user_id,
        'text' : coment_text,
        'reacciones' : [] 
    }

    resultado = comentarios_collection.insert_one(comentario)

    posts_collection.update_one(
        {'_id' : post_id},
        {'$push' : {'comentarios' : comentario}}
    )



    comentarios_collection.update_one(
         {'_id' : resultado.inserted_id},
         {'$push' : {'coment_id' : resultado.inserted_id}}
    )
    #comentario.coment_id = resultado.inserted_id

#def insertar_reaccion(self, reaccion: Likes, id):
#     react_id: int
# user_id: int
# reaccion: Reaccion
    # comentario = self.comentarios_collection.find_one({'_id' : id})
    # post = self.posts_collection.find_one({'_id' : id})

    # reaccion = {
    #     'reacted_id' : id,
    #     'user_id' : reaccion.user_id,
    #     'reaccion' : reaccion.reaccion
    # }

    # resultado = self.reacciones_collection.insert_one(reaccion)

    # if comentario: 
    #     self.comentarios_collection.update_one(
    #         {'_id' : id},
    #         {'$push' : {'reacciones' : reaccion}}
    #     )
    # elif post:
    #     self.posts_collection.update_one(
    #         {'_id' : id},
    #         {'$push' : {'reacciones' : reaccion}}
    #     )

# %%
#insertar_post(1, "Test1", [], [], [])
#insertar_post(1, "Test2", [], [], [])
#insertar_post(1, "Test3", [], [], [])
from bson import ObjectId


result = posts_collection.find_one({"_id": ObjectId("6712b6cd69123547e7c55c53")}, {"_id": 1})
if result:
    id_variable = result["_id"]
insertar_comentario(1, id_variable, "comentario test1")
obtener_posts(1)
# Out:
# [{'_id': ObjectId('6712b6cd69123547e7c55c53'),
#   'usuario_id': 1,
#   'text': 'Test1',
#   'images': [],
#   'reacciones': [],
#   'comentarios': [{'coment_id': 0,
#     'post_id': ObjectId('6712b6cd69123547e7c55c53'),
#     'user_id': 1,
#     'text': 'comentario test1',
#     'reacciones': [],
#     '_id': ObjectId('6712bbd969123547e7c55c68')}]},
#  {'_id': ObjectId('6712b6cd69123547e7c55c54'),
#   'usuario_id': 1,
#   'text': 'Test2',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b6cd69123547e7c55c55'),
#   'usuario_id': 1,
#   'text': 'Test3',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b81069123547e7c55c56'),
#   'usuario_id': 1,
#   'text': 'Test1',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b81069123547e7c55c57'),
#   'usuario_id': 1,
#   'text': 'Test2',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b81069123547e7c55c58'),
#   'usuario_id': 1,
#   'text': 'Test3',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b86f69123547e7c55c5a'),
#   'usuario_id': 1,
#   'text': 'Test1',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b86f69123547e7c55c5b'),
#   'usuario_id': 1,
#   'text': 'Test2',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b86f69123547e7c55c5c'),
#   'usuario_id': 1,
#   'text': 'Test3',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b89c69123547e7c55c5e'),
#   'usuario_id': 1,
#   'text': 'Test1',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b89c69123547e7c55c5f'),
#   'usuario_id': 1,
#   'text': 'Test2',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b89c69123547e7c55c60'),
#   'usuario_id': 1,
#   'text': 'Test3',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b8cc69123547e7c55c62'),
#   'usuario_id': 1,
#   'text': 'Test1',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b8cc69123547e7c55c63'),
#   'usuario_id': 1,
#   'text': 'Test2',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []},
#  {'_id': ObjectId('6712b8cc69123547e7c55c64'),
#   'usuario_id': 1,
#   'text': 'Test3',
#   'images': [],
#   'reacciones': [],
#   'comentarios': []}]
